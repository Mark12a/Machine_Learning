# %%
import pandas as pd
import numpy as np
from sklearn.tree import export_graphviz
from sklearn.tree import DecisionTreeClassifier
import pydot
import random

np.random.seed(42)
#random.seed(42)


class Dataset(object):
    def __init__(self, filename, header=None, set_header=True):
        
        self.filename = filename
        
        self.features_to_id = {}
        self.id_to_features = {}
        
        self.data = self.read_csv(self.filename, header, set_header=True)
        self.init(self.data)
    
    def read_csv(self, filename, header=None, set_header=False):
        
        if set_header:
            data_df = pd.read_csv(filename,header=0)
            data_df.columns = header
        
        else:
            data_df = pd.read_csv(filename,header=0)
    
        return data_df
    
    
    def init(self, data_df):
        
        cols_name = list(data_df.columns.values)
        
        for col in cols_name:
            
            self.features_to_id[col] = {}
            self.id_to_features[col] = {}
            
            data = data_df[col]
            
            names = list(set(list(data.values)))
            
            for i, name in enumerate(names):    
                self.features_to_id[col][name] = i
                self.id_to_features[col][i] = name
                
            
        return self.id_to_features, self.features_to_id
    
    def vectors(self):
        def map_feature_id(x):
            for col in self.features_to_id:
                x[col] = self.features_to_id[col][x[col]]
                
            return x

        return self.data.apply(func=map_feature_id, axis=1).values
    
    @staticmethod
    def split(data, test_size=0.4, random_state=42):
    
        test_index = data.sample(frac=test_size).index
        train_index = np.setdiff1d(data.index.values,test_index.values)

        train = data.loc[test_index]
        test = data.loc[train_index]

        return train, test
    
def preprocess(filename, header):
    
        data_df = pd.read_csv(filename,header=0)
        data_df.columns = header
    
        data_unacc = data_df.loc[data_df[header[-1]]=='unacc']
        train_unacc, test_unacc = Dataset.split(data_unacc)

        data_acc = data_df.loc[data_df[header[-1]] == 'acc']
        train_acc, test_acc = Dataset.split(data_acc)

        data_good = data_df.loc[data_df[header[-1]] == 'good']
        train_good, test_good = Dataset.split(data_good)

        data_vgood = data_df.loc[data_df[header[-1]] == 'vgood']
        train_vgood, test_vgood = Dataset.split(data_vgood)

        train = pd.concat([train_acc, train_unacc, train_good, train_vgood], axis=0).sample(frac=1).reset_index(drop=True)
        test = pd.concat([test_acc, test_unacc, test_good, test_vgood], axis=0).sample(frac=1).reset_index(drop=True)

        X_test = test[header[:-1]]
        y_test = test[header[-1]]

        train.to_csv('train.csv', header=header, index=0)
        X_test.to_csv('test_X.csv', header=header[:-1], index=0)
        y_test.to_csv('test_y.csv', header=header[-1], index=0)
        test.to_csv('test.csv', header=header, index=0)
        


def draw(tree, feature_names=[], class_names=[]):
    
    print(tree)
    
    export_graphviz(tree,out_file="tree.dot",class_names=class_names ,feature_names=feature_names, impurity=False,filled=True)
    
    (graph,) = pydot.graph_from_dot_file('tree.dot')
    
    graph.write_png('tree.png')

    
def train_tree(X_train, y_train, feature_names=[], class_names=[]):

    tree = DecisionTreeClassifier(criterion='entropy')
    tree.fit(X_train,y_train)
    
    print('Train score:{:.3f}'.format(tree.score(X_train,y_train)))
    
    draw(tree, feature_names, class_names)
    
    return tree

def test_tree(tree, X_test, y_test):
    
    print('Test score:{:.3f}'.format(tree.score(X_test,y_test)))
    
if __name__ == "__main__":
    
    filename = 'car.data.txt'
    header =['buying', 'maint', 'doors', 'persons', 'lug_boot', 'safety', 'class']
    
    #preprocess(filename, header)
    
    # load train set
    dataset = Dataset(filename, header, set_header=True)
    
    print(dataset.id_to_features)
    
    # train
    train = dataset.vectors()
    X = train[:, :-1]
    y = train[:, -1]
    
    tree = train_tree(X, y, feature_names=header[:-1], class_names=['acc', 'unacc', 'good', 'vgood'])
    
    # test
    test = Dataset('test.csv', header, set_header=True).vectors()
    X_test = test[:, :-1]
    y_test = test[:, -1]
    
    
    test_tree(tree, X_test, y_test)

    n_nodes = tree.tree_.node_count
    children_left = tree.tree_.children_left
    children_right = tree.tree_.children_right
    feature = tree.tree_.feature
    threshold = tree.tree_.threshold
    


    # The tree structure can be traversed to compute various properties such
    # as the depth of each node and whether or not it is a leaf.
    node_depth = np.zeros(shape=n_nodes, dtype=np.int64)
    is_leaves = np.zeros(shape=n_nodes, dtype=bool)
    stack = [(0, -1)]  # seed is the root node id and its parent depth
    while len(stack) > 0:
        node_id, parent_depth = stack.pop()
        node_depth[node_id] = parent_depth + 1

        # If we have a test node
        if (children_left[node_id] != children_right[node_id]):
            stack.append((children_left[node_id], parent_depth + 1))
            stack.append((children_right[node_id], parent_depth + 1))
        else:
            is_leaves[node_id] = True

    print("The binary tree structure has %s nodes and has "
          "the following tree structure:"
          % n_nodes)
    for i in range(n_nodes):
        if is_leaves[i]:
            print("%snode=%s leaf node." % (node_depth[i] * "\t", i))
        else:
            print("%snode=%s test node: go to node %s if X[:, %s] <= %s else to "
                  "node %s."
                  % (node_depth[i] * "\t",
                     i,
                     children_left[i],
                     header[feature[i]],
                     threshold[i],
                     children_right[i],
                     ))
    print()

    # First let's retrieve the decision path of each sample. The decision_path
    # method allows to retrieve the node indicator functions. A non zero element of
    # indicator matrix at the position (i, j) indicates that the sample i goes
    # through the node j.

    node_indicator = tree.decision_path(X_test)

    # Similarly, we can also have the leaves ids reached by each sample.

    leave_id = tree.apply(X_test)

    # Now, it's possible to get the tests that were used to predict a sample or
    # a group of samples. First, let's make it for the sample.

    sample_id = 0
    node_index = node_indicator.indices[node_indicator.indptr[sample_id]:
                                        node_indicator.indptr[sample_id + 1]]

    print('Rules used to predict sample %s: ' % sample_id)
    for node_id in node_index:
        if leave_id[sample_id] == node_id:
            continue

        if (X_test[sample_id, feature[node_id]] <= threshold[node_id]):
            threshold_sign = "<="
        else:
            threshold_sign = ">"

        print("decision id node %s : (X_test[%s, %s] (= %s) %s %s)"
              % (node_id,
                 sample_id,
                 header[feature[node_id]],
                 X_test[sample_id, feature[node_id]],
                 threshold_sign,
                 threshold[node_id]))

    # For a group of samples, we have the following common node.
    sample_ids = [0, 1]
    common_nodes = (node_indicator.toarray()[sample_ids].sum(axis=0) ==
                    len(sample_ids))

    common_node_id = np.arange(n_nodes)[common_nodes]

    print("\nThe following samples %s share the node %s in the tree"
          % (sample_ids, common_node_id))
    print("It is %s %% of all nodes." % (100 * len(common_node_id) / n_nodes,))
# Out:
# {'buying': {0: 'med', 1: 'vhigh', 2: 'low', 3: 'high'}, 'maint': {0: 'med', 1: 'vhigh', 2: 'low', 3: 'high'}, 'doors': {0: '4', 1: '5more', 2: '2', 3: '3'}, 'persons': {0: '4', 1: '2', 2: 'more'}, 'lug_boot': {0: 'small', 1: 'big', 2: 'med'}, 'safety': {0: 'med', 1: 'low', 2: 'high'}, 'class': {0: 'good', 1: 'acc', 2: 'unacc', 3: 'vgood'}}
# Train score:1.000
# DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')
# Test score:0.540
# The binary tree structure has 405 nodes and has the following tree structure:
# node=0 test node: go to node 1 if X[:, 5] <= 1.5 else to node 214.
# 	node=1 test node: go to node 2 if X[:, 5] <= 0.5 else to node 213.
# 		node=2 test node: go to node 3 if X[:, 4] <= 0.5 else to node 52.
# 			node=3 test node: go to node 4 if X[:, 0] <= 2.5 else to node 51.
# 				node=4 test node: go to node 5 if X[:, 0] <= 1.5 else to node 30.
# 					node=5 test node: go to node 6 if X[:, 0] <= 0.5 else to node 29.
# 						node=6 test node: go to node 7 if X[:, 1] <= 2.5 else to node 28.
# 							node=7 test node: go to node 8 if X[:, 3] <= 0.5 else to node 13.
# 								node=8 test node: go to node 9 if X[:, 1] <= 0.5 else to node 10.
# 									node=9 leaf node.
# 									node=10 test node: go to node 11 if X[:, 1] <= 1.5 else to node 12.
# 										node=11 leaf node.
# 										node=12 leaf node.
# 								node=13 test node: go to node 14 if X[:, 3] <= 1.5 else to node 15.
# 									node=14 leaf node.
# 									node=15 test node: go to node 16 if X[:, 1] <= 0.5 else to node 21.
# 										node=16 test node: go to node 17 if X[:, 2] <= 1.5 else to node 18.
# 											node=17 leaf node.
# 											node=18 test node: go to node 19 if X[:, 2] <= 2.5 else to node 20.
# 												node=19 leaf node.
# 												node=20 leaf node.
# 										node=21 test node: go to node 22 if X[:, 1] <= 1.5 else to node 23.
# 											node=22 leaf node.
# 											node=23 test node: go to node 24 if X[:, 2] <= 1.5 else to node 25.
# 												node=24 leaf node.
# 												node=25 test node: go to node 26 if X[:, 2] <= 2.5 else to node 27.
# 													node=26 leaf node.
# 													node=27 leaf node.
# 							node=28 leaf node.
# 						node=29 leaf node.
# 					node=30 test node: go to node 31 if X[:, 3] <= 0.5 else to node 36.
# 						node=31 test node: go to node 32 if X[:, 1] <= 1.5 else to node 35.
# 							node=32 test node: go to node 33 if X[:, 1] <= 0.5 else to node 34.
# 								node=33 leaf node.
# 								node=34 leaf node.
# 							node=35 leaf node.
# 						node=36 test node: go to node 37 if X[:, 3] <= 1.5 else to node 38.
# 							node=37 leaf node.
# 							node=38 test node: go to node 39 if X[:, 1] <= 1.5 else to node 46.
# 								node=39 test node: go to node 40 if X[:, 1] <= 0.5 else to node 45.
# 									node=40 test node: go to node 41 if X[:, 2] <= 1.5 else to node 42.
# 										node=41 leaf node.
# 										node=42 test node: go to node 43 if X[:, 2] <= 2.5 else to node 44.
# 											node=43 leaf node.
# 											node=44 leaf node.
# 									node=45 leaf node.
# 								node=46 test node: go to node 47 if X[:, 2] <= 1.5 else to node 48.
# 									node=47 leaf node.
# 									node=48 test node: go to node 49 if X[:, 2] <= 2.5 else to node 50.
# 										node=49 leaf node.
# 										node=50 leaf node.
# 				node=51 leaf node.
# 			node=52 test node: go to node 53 if X[:, 3] <= 1.5 else to node 124.
# 				node=53 test node: go to node 54 if X[:, 3] <= 0.5 else to node 123.
# 					node=54 test node: go to node 55 if X[:, 0] <= 2.5 else to node 110.
# 						node=55 test node: go to node 56 if X[:, 0] <= 1.5 else to node 91.
# 							node=56 test node: go to node 57 if X[:, 0] <= 0.5 else to node 76.
# 								node=57 test node: go to node 58 if X[:, 1] <= 1.5 else to node 65.
# 									node=58 test node: go to node 59 if X[:, 4] <= 1.5 else to node 60.
# 										node=59 leaf node.
# 										node=60 test node: go to node 61 if X[:, 2] <= 1.5 else to node 62.
# 											node=61 leaf node.
# 											node=62 test node: go to node 63 if X[:, 1] <= 0.5 else to node 64.
# 												node=63 leaf node.
# 												node=64 leaf node.
# 									node=65 test node: go to node 66 if X[:, 1] <= 2.5 else to node 71.
# 										node=66 test node: go to node 67 if X[:, 2] <= 1.5 else to node 68.
# 											node=67 leaf node.
# 											node=68 test node: go to node 69 if X[:, 4] <= 1.5 else to node 70.
# 												node=69 leaf node.
# 												node=70 leaf node.
# 										node=71 test node: go to node 72 if X[:, 2] <= 1.5 else to node 73.
# 											node=72 leaf node.
# 											node=73 test node: go to node 74 if X[:, 4] <= 1.5 else to node 75.
# 												node=74 leaf node.
# 												node=75 leaf node.
# 								node=76 test node: go to node 77 if X[:, 1] <= 2.5 else to node 90.
# 									node=77 test node: go to node 78 if X[:, 1] <= 0.5 else to node 83.
# 										node=78 test node: go to node 79 if X[:, 2] <= 1.5 else to node 80.
# 											node=79 leaf node.
# 											node=80 test node: go to node 81 if X[:, 4] <= 1.5 else to node 82.
# 												node=81 leaf node.
# 												node=82 leaf node.
# 										node=83 test node: go to node 84 if X[:, 1] <= 1.5 else to node 85.
# 											node=84 leaf node.
# 											node=85 test node: go to node 86 if X[:, 2] <= 1.5 else to node 87.
# 												node=86 leaf node.
# 												node=87 test node: go to node 88 if X[:, 4] <= 1.5 else to node 89.
# 													node=88 leaf node.
# 													node=89 leaf node.
# 									node=90 leaf node.
# 							node=91 test node: go to node 92 if X[:, 1] <= 2.5 else to node 109.
# 								node=92 test node: go to node 93 if X[:, 4] <= 1.5 else to node 98.
# 									node=93 test node: go to node 94 if X[:, 1] <= 0.5 else to node 95.
# 										node=94 leaf node.
# 										node=95 test node: go to node 96 if X[:, 1] <= 1.5 else to node 97.
# 											node=96 leaf node.
# 											node=97 leaf node.
# 									node=98 test node: go to node 99 if X[:, 2] <= 1.5 else to node 104.
# 										node=99 test node: go to node 100 if X[:, 1] <= 0.5 else to node 101.
# 											node=100 leaf node.
# 											node=101 test node: go to node 102 if X[:, 1] <= 1.5 else to node 103.
# 												node=102 leaf node.
# 												node=103 leaf node.
# 										node=104 test node: go to node 105 if X[:, 1] <= 0.5 else to node 106.
# 											node=105 leaf node.
# 											node=106 test node: go to node 107 if X[:, 1] <= 1.5 else to node 108.
# 												node=107 leaf node.
# 												node=108 leaf node.
# 								node=109 leaf node.
# 						node=110 test node: go to node 111 if X[:, 2] <= 1.5 else to node 116.
# 							node=111 test node: go to node 112 if X[:, 1] <= 1.5 else to node 115.
# 								node=112 test node: go to node 113 if X[:, 1] <= 0.5 else to node 114.
# 									node=113 leaf node.
# 									node=114 leaf node.
# 								node=115 leaf node.
# 							node=116 test node: go to node 117 if X[:, 4] <= 1.5 else to node 122.
# 								node=117 test node: go to node 118 if X[:, 1] <= 1.5 else to node 121.
# 									node=118 test node: go to node 119 if X[:, 1] <= 0.5 else to node 120.
# 										node=119 leaf node.
# 										node=120 leaf node.
# 									node=121 leaf node.
# 								node=122 leaf node.
# 					node=123 leaf node.
# 				node=124 test node: go to node 125 if X[:, 0] <= 2.5 else to node 196.
# 					node=125 test node: go to node 126 if X[:, 0] <= 1.5 else to node 171.
# 						node=126 test node: go to node 127 if X[:, 0] <= 0.5 else to node 152.
# 							node=127 test node: go to node 128 if X[:, 1] <= 1.5 else to node 137.
# 								node=128 test node: go to node 129 if X[:, 1] <= 0.5 else to node 130.
# 									node=129 leaf node.
# 									node=130 test node: go to node 131 if X[:, 2] <= 1.5 else to node 132.
# 										node=131 leaf node.
# 										node=132 test node: go to node 133 if X[:, 2] <= 2.5 else to node 136.
# 											node=133 test node: go to node 134 if X[:, 4] <= 1.5 else to node 135.
# 												node=134 leaf node.
# 												node=135 leaf node.
# 											node=136 leaf node.
# 								node=137 test node: go to node 138 if X[:, 1] <= 2.5 else to node 145.
# 									node=138 test node: go to node 139 if X[:, 2] <= 1.5 else to node 140.
# 										node=139 leaf node.
# 										node=140 test node: go to node 141 if X[:, 4] <= 1.5 else to node 142.
# 											node=141 leaf node.
# 											node=142 test node: go to node 143 if X[:, 2] <= 2.5 else to node 144.
# 												node=143 leaf node.
# 												node=144 leaf node.
# 									node=145 test node: go to node 146 if X[:, 4] <= 1.5 else to node 147.
# 										node=146 leaf node.
# 										node=147 test node: go to node 148 if X[:, 2] <= 1.5 else to node 149.
# 											node=148 leaf node.
# 											node=149 test node: go to node 150 if X[:, 2] <= 2.5 else to node 151.
# 												node=150 leaf node.
# 												node=151 leaf node.
# 							node=152 test node: go to node 153 if X[:, 1] <= 2.5 else to node 170.
# 								node=153 test node: go to node 154 if X[:, 1] <= 0.5 else to node 161.
# 									node=154 test node: go to node 155 if X[:, 2] <= 1.5 else to node 156.
# 										node=155 leaf node.
# 										node=156 test node: go to node 157 if X[:, 4] <= 1.5 else to node 158.
# 											node=157 leaf node.
# 											node=158 test node: go to node 159 if X[:, 2] <= 2.5 else to node 160.
# 												node=159 leaf node.
# 												node=160 leaf node.
# 									node=161 test node: go to node 162 if X[:, 1] <= 1.5 else to node 163.
# 										node=162 leaf node.
# 										node=163 test node: go to node 164 if X[:, 4] <= 1.5 else to node 165.
# 											node=164 leaf node.
# 											node=165 test node: go to node 166 if X[:, 2] <= 1.5 else to node 167.
# 												node=166 leaf node.
# 												node=167 test node: go to node 168 if X[:, 2] <= 2.5 else to node 169.
# 													node=168 leaf node.
# 													node=169 leaf node.
# 								node=170 leaf node.
# 						node=171 test node: go to node 172 if X[:, 1] <= 2.5 else to node 195.
# 							node=172 test node: go to node 173 if X[:, 1] <= 0.5 else to node 180.
# 								node=173 test node: go to node 174 if X[:, 2] <= 1.5 else to node 175.
# 									node=174 leaf node.
# 									node=175 test node: go to node 176 if X[:, 2] <= 2.5 else to node 179.
# 										node=176 test node: go to node 177 if X[:, 4] <= 1.5 else to node 178.
# 											node=177 leaf node.
# 											node=178 leaf node.
# 										node=179 leaf node.
# 								node=180 test node: go to node 181 if X[:, 1] <= 1.5 else to node 188.
# 									node=181 test node: go to node 182 if X[:, 4] <= 1.5 else to node 183.
# 										node=182 leaf node.
# 										node=183 test node: go to node 184 if X[:, 2] <= 1.5 else to node 185.
# 											node=184 leaf node.
# 											node=185 test node: go to node 186 if X[:, 2] <= 2.5 else to node 187.
# 												node=186 leaf node.
# 												node=187 leaf node.
# 									node=188 test node: go to node 189 if X[:, 4] <= 1.5 else to node 190.
# 										node=189 leaf node.
# 										node=190 test node: go to node 191 if X[:, 2] <= 1.5 else to node 192.
# 											node=191 leaf node.
# 											node=192 test node: go to node 193 if X[:, 2] <= 2.5 else to node 194.
# 												node=193 leaf node.
# 												node=194 leaf node.
# 							node=195 leaf node.
# 					node=196 test node: go to node 197 if X[:, 1] <= 1.5 else to node 206.
# 						node=197 test node: go to node 198 if X[:, 1] <= 0.5 else to node 205.
# 							node=198 test node: go to node 199 if X[:, 2] <= 1.5 else to node 200.
# 								node=199 leaf node.
# 								node=200 test node: go to node 201 if X[:, 2] <= 2.5 else to node 204.
# 									node=201 test node: go to node 202 if X[:, 4] <= 1.5 else to node 203.
# 										node=202 leaf node.
# 										node=203 leaf node.
# 									node=204 leaf node.
# 							node=205 leaf node.
# 						node=206 test node: go to node 207 if X[:, 2] <= 1.5 else to node 208.
# 							node=207 leaf node.
# 							node=208 test node: go to node 209 if X[:, 2] <= 2.5 else to node 212.
# 								node=209 test node: go to node 210 if X[:, 4] <= 1.5 else to node 211.
# 									node=210 leaf node.
# 									node=211 leaf node.
# 								node=212 leaf node.
# 		node=213 leaf node.
# 	node=214 test node: go to node 215 if X[:, 3] <= 0.5 else to node 292.
# 		node=215 test node: go to node 216 if X[:, 4] <= 0.5 else to node 243.
# 			node=216 test node: go to node 217 if X[:, 1] <= 0.5 else to node 222.
# 				node=217 test node: go to node 218 if X[:, 0] <= 1.5 else to node 219.
# 					node=218 leaf node.
# 					node=219 test node: go to node 220 if X[:, 0] <= 2.5 else to node 221.
# 						node=220 leaf node.
# 						node=221 leaf node.
# 				node=222 test node: go to node 223 if X[:, 1] <= 1.5 else to node 230.
# 					node=223 test node: go to node 224 if X[:, 0] <= 0.5 else to node 225.
# 						node=224 leaf node.
# 						node=225 test node: go to node 226 if X[:, 0] <= 1.5 else to node 227.
# 							node=226 leaf node.
# 							node=227 test node: go to node 228 if X[:, 0] <= 2.5 else to node 229.
# 								node=228 leaf node.
# 								node=229 leaf node.
# 					node=230 test node: go to node 231 if X[:, 1] <= 2.5 else to node 238.
# 						node=231 test node: go to node 232 if X[:, 0] <= 0.5 else to node 233.
# 							node=232 leaf node.
# 							node=233 test node: go to node 234 if X[:, 0] <= 1.5 else to node 235.
# 								node=234 leaf node.
# 								node=235 test node: go to node 236 if X[:, 0] <= 2.5 else to node 237.
# 									node=236 leaf node.
# 									node=237 leaf node.
# 						node=238 test node: go to node 239 if X[:, 0] <= 1.5 else to node 242.
# 							node=239 test node: go to node 240 if X[:, 0] <= 0.5 else to node 241.
# 								node=240 leaf node.
# 								node=241 leaf node.
# 							node=242 leaf node.
# 			node=243 test node: go to node 244 if X[:, 0] <= 2.5 else to node 287.
# 				node=244 test node: go to node 245 if X[:, 0] <= 1.5 else to node 268.
# 					node=245 test node: go to node 246 if X[:, 0] <= 0.5 else to node 261.
# 						node=246 test node: go to node 247 if X[:, 1] <= 2.5 else to node 260.
# 							node=247 test node: go to node 248 if X[:, 1] <= 1.5 else to node 255.
# 								node=248 test node: go to node 249 if X[:, 1] <= 0.5 else to node 254.
# 									node=249 test node: go to node 250 if X[:, 2] <= 1.5 else to node 251.
# 										node=250 leaf node.
# 										node=251 test node: go to node 252 if X[:, 4] <= 1.5 else to node 253.
# 											node=252 leaf node.
# 											node=253 leaf node.
# 									node=254 leaf node.
# 								node=255 test node: go to node 256 if X[:, 4] <= 1.5 else to node 257.
# 									node=256 leaf node.
# 									node=257 test node: go to node 258 if X[:, 2] <= 1.5 else to node 259.
# 										node=258 leaf node.
# 										node=259 leaf node.
# 							node=260 leaf node.
# 						node=261 test node: go to node 262 if X[:, 1] <= 0.5 else to node 263.
# 							node=262 leaf node.
# 							node=263 test node: go to node 264 if X[:, 1] <= 1.5 else to node 265.
# 								node=264 leaf node.
# 								node=265 test node: go to node 266 if X[:, 1] <= 2.5 else to node 267.
# 									node=266 leaf node.
# 									node=267 leaf node.
# 					node=268 test node: go to node 269 if X[:, 4] <= 1.5 else to node 274.
# 						node=269 test node: go to node 270 if X[:, 1] <= 1.5 else to node 273.
# 							node=270 test node: go to node 271 if X[:, 1] <= 0.5 else to node 272.
# 								node=271 leaf node.
# 								node=272 leaf node.
# 							node=273 leaf node.
# 						node=274 test node: go to node 275 if X[:, 2] <= 1.5 else to node 280.
# 							node=275 test node: go to node 276 if X[:, 1] <= 1.5 else to node 279.
# 								node=276 test node: go to node 277 if X[:, 1] <= 0.5 else to node 278.
# 									node=277 leaf node.
# 									node=278 leaf node.
# 								node=279 leaf node.
# 							node=280 test node: go to node 281 if X[:, 1] <= 0.5 else to node 282.
# 								node=281 leaf node.
# 								node=282 test node: go to node 283 if X[:, 1] <= 1.5 else to node 284.
# 									node=283 leaf node.
# 									node=284 test node: go to node 285 if X[:, 1] <= 2.5 else to node 286.
# 										node=285 leaf node.
# 										node=286 leaf node.
# 				node=287 test node: go to node 288 if X[:, 1] <= 1.5 else to node 291.
# 					node=288 test node: go to node 289 if X[:, 1] <= 0.5 else to node 290.
# 						node=289 leaf node.
# 						node=290 leaf node.
# 					node=291 leaf node.
# 		node=292 test node: go to node 293 if X[:, 3] <= 1.5 else to node 294.
# 			node=293 leaf node.
# 			node=294 test node: go to node 295 if X[:, 4] <= 0.5 else to node 352.
# 				node=295 test node: go to node 296 if X[:, 2] <= 1.5 else to node 323.
# 					node=296 test node: go to node 297 if X[:, 1] <= 0.5 else to node 302.
# 						node=297 test node: go to node 298 if X[:, 0] <= 1.5 else to node 299.
# 							node=298 leaf node.
# 							node=299 test node: go to node 300 if X[:, 0] <= 2.5 else to node 301.
# 								node=300 leaf node.
# 								node=301 leaf node.
# 						node=302 test node: go to node 303 if X[:, 1] <= 1.5 else to node 310.
# 							node=303 test node: go to node 304 if X[:, 0] <= 0.5 else to node 305.
# 								node=304 leaf node.
# 								node=305 test node: go to node 306 if X[:, 0] <= 1.5 else to node 307.
# 									node=306 leaf node.
# 									node=307 test node: go to node 308 if X[:, 0] <= 2.5 else to node 309.
# 										node=308 leaf node.
# 										node=309 leaf node.
# 							node=310 test node: go to node 311 if X[:, 1] <= 2.5 else to node 318.
# 								node=311 test node: go to node 312 if X[:, 0] <= 0.5 else to node 313.
# 									node=312 leaf node.
# 									node=313 test node: go to node 314 if X[:, 0] <= 1.5 else to node 315.
# 										node=314 leaf node.
# 										node=315 test node: go to node 316 if X[:, 0] <= 2.5 else to node 317.
# 											node=316 leaf node.
# 											node=317 leaf node.
# 								node=318 test node: go to node 319 if X[:, 0] <= 1.5 else to node 322.
# 									node=319 test node: go to node 320 if X[:, 0] <= 0.5 else to node 321.
# 										node=320 leaf node.
# 										node=321 leaf node.
# 									node=322 leaf node.
# 					node=323 test node: go to node 324 if X[:, 2] <= 2.5 else to node 325.
# 						node=324 leaf node.
# 						node=325 test node: go to node 326 if X[:, 1] <= 0.5 else to node 331.
# 							node=326 test node: go to node 327 if X[:, 0] <= 1.5 else to node 328.
# 								node=327 leaf node.
# 								node=328 test node: go to node 329 if X[:, 0] <= 2.5 else to node 330.
# 									node=329 leaf node.
# 									node=330 leaf node.
# 							node=331 test node: go to node 332 if X[:, 1] <= 1.5 else to node 339.
# 								node=332 test node: go to node 333 if X[:, 0] <= 0.5 else to node 334.
# 									node=333 leaf node.
# 									node=334 test node: go to node 335 if X[:, 0] <= 1.5 else to node 336.
# 										node=335 leaf node.
# 										node=336 test node: go to node 337 if X[:, 0] <= 2.5 else to node 338.
# 											node=337 leaf node.
# 											node=338 leaf node.
# 								node=339 test node: go to node 340 if X[:, 1] <= 2.5 else to node 347.
# 									node=340 test node: go to node 341 if X[:, 0] <= 0.5 else to node 342.
# 										node=341 leaf node.
# 										node=342 test node: go to node 343 if X[:, 0] <= 1.5 else to node 344.
# 											node=343 leaf node.
# 											node=344 test node: go to node 345 if X[:, 0] <= 2.5 else to node 346.
# 												node=345 leaf node.
# 												node=346 leaf node.
# 									node=347 test node: go to node 348 if X[:, 0] <= 1.5 else to node 351.
# 										node=348 test node: go to node 349 if X[:, 0] <= 0.5 else to node 350.
# 											node=349 leaf node.
# 											node=350 leaf node.
# 										node=351 leaf node.
# 				node=352 test node: go to node 353 if X[:, 0] <= 2.5 else to node 400.
# 					node=353 test node: go to node 354 if X[:, 0] <= 1.5 else to node 381.
# 						node=354 test node: go to node 355 if X[:, 0] <= 0.5 else to node 374.
# 							node=355 test node: go to node 356 if X[:, 1] <= 2.5 else to node 373.
# 								node=356 test node: go to node 357 if X[:, 1] <= 1.5 else to node 366.
# 									node=357 test node: go to node 358 if X[:, 1] <= 0.5 else to node 365.
# 										node=358 test node: go to node 359 if X[:, 4] <= 1.5 else to node 360.
# 											node=359 leaf node.
# 											node=360 test node: go to node 361 if X[:, 2] <= 1.5 else to node 362.
# 												node=361 leaf node.
# 												node=362 test node: go to node 363 if X[:, 2] <= 2.5 else to node 364.
# 													node=363 leaf node.
# 													node=364 leaf node.
# 										node=365 leaf node.
# 									node=366 test node: go to node 367 if X[:, 4] <= 1.5 else to node 368.
# 										node=367 leaf node.
# 										node=368 test node: go to node 369 if X[:, 2] <= 1.5 else to node 370.
# 											node=369 leaf node.
# 											node=370 test node: go to node 371 if X[:, 2] <= 2.5 else to node 372.
# 												node=371 leaf node.
# 												node=372 leaf node.
# 								node=373 leaf node.
# 							node=374 test node: go to node 375 if X[:, 1] <= 0.5 else to node 376.
# 								node=375 leaf node.
# 								node=376 test node: go to node 377 if X[:, 1] <= 1.5 else to node 378.
# 									node=377 leaf node.
# 									node=378 test node: go to node 379 if X[:, 1] <= 2.5 else to node 380.
# 										node=379 leaf node.
# 										node=380 leaf node.
# 						node=381 test node: go to node 382 if X[:, 1] <= 1.5 else to node 391.
# 							node=382 test node: go to node 383 if X[:, 1] <= 0.5 else to node 390.
# 								node=383 test node: go to node 384 if X[:, 2] <= 1.5 else to node 385.
# 									node=384 leaf node.
# 									node=385 test node: go to node 386 if X[:, 2] <= 2.5 else to node 389.
# 										node=386 test node: go to node 387 if X[:, 4] <= 1.5 else to node 388.
# 											node=387 leaf node.
# 											node=388 leaf node.
# 										node=389 leaf node.
# 								node=390 leaf node.
# 							node=391 test node: go to node 392 if X[:, 4] <= 1.5 else to node 393.
# 								node=392 leaf node.
# 								node=393 test node: go to node 394 if X[:, 2] <= 1.5 else to node 395.
# 									node=394 leaf node.
# 									node=395 test node: go to node 396 if X[:, 2] <= 2.5 else to node 399.
# 										node=396 test node: go to node 397 if X[:, 1] <= 2.5 else to node 398.
# 											node=397 leaf node.
# 											node=398 leaf node.
# 										node=399 leaf node.
# 					node=400 test node: go to node 401 if X[:, 1] <= 1.5 else to node 404.
# 						node=401 test node: go to node 402 if X[:, 1] <= 0.5 else to node 403.
# 							node=402 leaf node.
# 							node=403 leaf node.
# 						node=404 leaf node.
#
# Rules used to predict sample 0:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-49-5fc132cb1a07> in <module>
#     229               % (node_id,
#     230                  sample_id,
# --> 231                  dataset.id_to_features[feature[node_id]],
#     232                  X_test[sample_id, feature[node_id]],
#     233                  threshold_sign,
#
# KeyError: 5

# %%
"""
=========================================
Understanding the decision tree structure
=========================================

The decision tree structure can be analysed to gain further insight on the
relation between the features and the target to predict. In this example, we
show how to retrieve:

- the binary tree structure;
- the depth of each node and whether or not it's a leaf;
- the nodes that were reached by a sample using the ``decision_path`` method;
- the leaf that was reached by a sample using the apply method;
- the rules that were used to predict a sample;
- the decision path shared by a group of samples.

"""
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.datasets import load_iris
from sklearn.tree import DecisionTreeClassifier

iris = load_iris()
X = iris.data
y = iris.target
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)

tree = DecisionTreeClassifier(max_leaf_nodes=3, random_state=0)
tree.fit(X_train, y_train)

# The decision estimator has an attribute called tree_  which stores the entire
# tree structure and allows access to low level attributes. The binary tree
# tree_ is represented as a number of parallel arrays. The i-th element of each
# array holds information about the node `i`. Node 0 is the tree's root. NOTE:
# Some of the arrays only apply to either leaves or split nodes, resp. In this
# case the values of nodes of the other type are arbitrary!
#
# Among those arrays, we have:
#   - left_child, id of the left child of the node
#   - right_child, id of the right child of the node
#   - feature, feature used for splitting the node
#   - threshold, threshold value at the node
#

# Using those arrays, we can parse the tree structure:

n_nodes = tree.tree_.node_count
children_left = tree.tree_.children_left
children_right = tree.tree_.children_right
feature = tree.tree_.feature
threshold = tree.tree_.threshold


# The tree structure can be traversed to compute various properties such
# as the depth of each node and whether or not it is a leaf.
node_depth = np.zeros(shape=n_nodes, dtype=np.int64)
is_leaves = np.zeros(shape=n_nodes, dtype=bool)
stack = [(0, -1)]  # seed is the root node id and its parent depth
while len(stack) > 0:
    node_id, parent_depth = stack.pop()
    node_depth[node_id] = parent_depth + 1

    # If we have a test node
    if (children_left[node_id] != children_right[node_id]):
        stack.append((children_left[node_id], parent_depth + 1))
        stack.append((children_right[node_id], parent_depth + 1))
    else:
        is_leaves[node_id] = True

print("The binary tree structure has %s nodes and has "
      "the following tree structure:"
      % n_nodes)
for i in range(n_nodes):
    if is_leaves[i]:
        print("%snode=%s leaf node." % (node_depth[i] * "\t", i))
    else:
        print("%snode=%s test node: go to node %s if X[:, %s] <= %s else to "
              "node %s."
              % (node_depth[i] * "\t",
                 i,
                 children_left[i],
                 feature[i],
                 threshold[i],
                 children_right[i],
                 ))
print()

# First let's retrieve the decision path of each sample. The decision_path
# method allows to retrieve the node indicator functions. A non zero element of
# indicator matrix at the position (i, j) indicates that the sample i goes
# through the node j.

node_indicator = tree.decision_path(X_test)

# Similarly, we can also have the leaves ids reached by each sample.

leave_id = tree.apply(X_test)

# Now, it's possible to get the tests that were used to predict a sample or
# a group of samples. First, let's make it for the sample.

sample_id = 0
node_index = node_indicator.indices[node_indicator.indptr[sample_id]:
                                    node_indicator.indptr[sample_id + 1]]

print('Rules used to predict sample %s: ' % sample_id)
for node_id in node_index:
    if leave_id[sample_id] == node_id:
        continue

    if (X_test[sample_id, feature[node_id]] <= threshold[node_id]):
        threshold_sign = "<="
    else:
        threshold_sign = ">"

    print("decision id node %s : (X_test[%s, %s] (= %s) %s %s)"
          % (node_id,
             sample_id,
             feature[node_id],
             X_test[sample_id, feature[node_id]],
             threshold_sign,
             threshold[node_id]))

# For a group of samples, we have the following common node.
sample_ids = [0, 1]
common_nodes = (node_indicator.toarray()[sample_ids].sum(axis=0) ==
                len(sample_ids))

common_node_id = np.arange(n_nodes)[common_nodes]

print("\nThe following samples %s share the node %s in the tree"
      % (sample_ids, common_node_id))
print("It is %s %% of all nodes." % (100 * len(common_node_id) / n_nodes,))
# Out:
# The binary tree structure has 5 nodes and has the following tree structure:
# node=0 test node: go to node 1 if X[:, 3] <= 0.800000011920929 else to node 2.
# 	node=1 leaf node.
# 	node=2 test node: go to node 3 if X[:, 2] <= 4.950000047683716 else to node 4.
# 		node=3 leaf node.
# 		node=4 leaf node.
#
# Rules used to predict sample 0:
# decision id node 0 : (X_test[0, 3] (= 2.4) > 0.800000011920929)
# decision id node 2 : (X_test[0, 2] (= 5.1) > 4.950000047683716)
#
# The following samples [0, 1] share the node [0 2] in the tree
# It is 40.0 % of all nodes.
